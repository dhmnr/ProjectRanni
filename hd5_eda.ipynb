# %%
import h5py

# %%
filename = "my_recording.h5"

h5 = h5py.File(filename,'r')

# %%
h5.keys()
# Out:
# <KeysViewHDF5 ['frames', 'inputs', 'latencies', 'memory_data', 'timestamps']>

# %%
h5['inputs'].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 h5['inputs'].attr
#
# AttributeError: 'Dataset' object has no attribute 'attr'
